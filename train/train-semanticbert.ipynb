# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/datasets/ppark8798/smartbug/train_chunks_subset.pt
# /kaggle/input/datasets/ppark8798/smartbug/test_chunks.pt
# /kaggle/input/datasets/ppark8798/smartbug/test_chunks_eval.pt
# /kaggle/input/datasets/ppark8798/smartbug/val_chunks.pt
# /kaggle/input/datasets/ppark8798/smartbug/train_chunks.pt
# /kaggle/input/datasets/mailuongg/sample-for-testing-data/sample_val.pt
# /kaggle/input/datasets/mailuongg/sample-for-testing-data/sample_train.pt
# /kaggle/input/datasets/mailuongg/codebert-contrastive-2/actual_model/evaluate.py
# /kaggle/input/datasets/mailuongg/codebert-contrastive-2/actual_model/contrastive_dataset.py
# /kaggle/input/datasets/mailuongg/codebert-contrastive-2/actual_model/codebert_contrastive.py
# /kaggle/input/datasets/mailuongg/codebert-contrastive-2/actual_model/__init__.py
# /kaggle/input/datasets/mailuongg/codebert-contrastive-2/actual_model/interpret.py
# /kaggle/input/datasets/mailuongg/codebert-contrastive-2/actual_model/train_contrastive.py
# ...

# %%
# !ls /kaggle/input/datasets/ppark8798/smartbug
# Out:
# test_chunks_eval.pt  train_chunks.pt	     val_chunks.pt
# test_chunks.pt	     train_chunks_subset.pt

# %%
# !mkdir -p /kaggle/working/project
# !cp -r /kaggle/input/datasets/mailuongg/codebert-contrastive-2/* /kaggle/working/project/
# %cd /kaggle/working/project
# !find . -maxdepth 3 -type f | sort
# Out:
# /kaggle/working/project
# ./actual_model/codebert_contrastive.py
# ./actual_model/contrastive_dataset.py
# ./actual_model/evaluate.py
# ./actual_model/__init__.py
# ./actual_model/interpret.py
# ./actual_model/train_contrastive.py

# %%
import torch
import numpy
import sklearn
import tqdm
import transformers

print("basic packages are available")
# Out:
# basic packages are available

# %%
import os


print("cwd:", os.getcwd())
print("cuda available:", torch.cuda.is_available())
print("device count:", torch.cuda.device_count())
# Out:
# cwd: /kaggle/working/project
# cuda available: True
# device count: 2

# %% [markdown]
# just checking impl is alright on a small sample train and val dataset

# %%
#!python actual_model/train_contrastive.py --train-path /kaggle/input/datasets/mailuongg/sample-for-testing-data/sample_train.pt --val-path /kaggle/input/datasets/mailuongg/sample-for-testing-data/sample_val.pt --output-dir /kaggle/working/outputs --batch-size 16 --epochs 3 --learning-rate 2e-5 --selection-metric pr_auc --freeze-lower-layers 6

# %%
# !python actual_model/train_contrastive.py --train-path /kaggle/input/datasets/ppark8798/smartbug/train_chunks_subset.pt --val-path /kaggle/input/datasets/ppark8798/smartbug/val_chunks.pt --output-dir /kaggle/working/outputs --batch-size 16 --epochs 3 --learning-rate 2e-5 --selection-metric pr_auc --freeze-lower-layers 6
# Out:
# ...
# config.json: 100%|█████████████████████████████| 498/498 [00:00<00:00, 2.49MB/s]
# pytorch_model.bin:  82%|█████████████████▉    | 407M/499M [00:03<00:00, 116MB/s]
# Loading weights: 100%|█| 199/199 [00:00<00:00, 3534.69it/s, Materializing param=
# model.safetensors:  13%|██▊                  | 67.1M/499M [00:00<00:00, 581MB/s]Training on cuda | dataset size=51617 | batches=3227
# Validation set loaded | size=33201 | batches=2076
#
# model.safetensors: 100%|██████████████████████| 499M/499M [00:02<00:00, 210MB/s]
#
# Epoch 1/3:   0%| | 0/3227 [00:04<?, ?it/s, clf=0.9046, loss=1.4804, triplet=1.02
# Epoch 1/3:   0%| | 1/3227 [00:04<4:13:59,  4.72s/it, clf=0.9046, loss=1.4804, tr
# Epoch 1/3:   0%| | 1/3227 [00:07<4:13:59,  4.72s/it, clf=0.9250, loss=1.4461, tr
# Epoch 1/3:   0%| | 2/3227 [00:07<3:06:51,  3.48s/it, clf=0.9250, loss=1.4461, tr
# Epoch 1/3:   0%| | 2/3227 [00:09<3:06:51,  3.48s/it, clf=0.8239, loss=1.3846, tr
# ...
